# %%
# connect to milvus db

from langchain_milvus import Milvus
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pymilvus import connections, Collection, FieldSchema, CollectionSchema, DataType, utility
import os 
from dotenv import load_dotenv

load_dotenv()
MILVUS_URI = "https://in03-d8f19805795ae7b.serverless.aws-eu-central-1.cloud.zilliz.com"
MILVUS_TOKEN = "e548ca0b2cdf6d09cbe43de608c2a80a52d001d36248cdbc3aab61e9ba2ff49eb57fe576b2c7d792fab406f1cb35470b860abf96"
MILVUS_COLLECTION_NAME = "translations"

# Connect to Milvus
connections.connect(
    uri=MILVUS_URI,
    token=MILVUS_TOKEN
)

# Get embedding dimension (Google embedding-001 uses 768 dimensions)
embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key=os.getenv("GEMINI_API_KEY"))
EMBEDDING_DIM = 768  # Google embedding-001 dimension

# Define custom schema with all required fields
# This prevents schema resets by explicitly defining the structure
id_field = FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=True)
source_text_field = FieldSchema(name="source_text", dtype=DataType.VARCHAR, max_length=10000)
source_language_field = FieldSchema(name="source_language", dtype=DataType.VARCHAR, max_length=50)
translation_text_field = FieldSchema(name="translation_text", dtype=DataType.VARCHAR, max_length=10000)
translation_language_field = FieldSchema(name="translation_language", dtype=DataType.VARCHAR, max_length=50)
# Vector field for translation_text and source embeddings
source_vector_field = FieldSchema(name="source_vector", dtype=DataType.FLOAT_VECTOR, dim=EMBEDDING_DIM)
translation_vector_field = FieldSchema(name="translation_vector", dtype=DataType.FLOAT_VECTOR, dim=EMBEDDING_DIM)

# Create collection schema
schema = CollectionSchema(
    fields=[
        id_field,
        source_text_field,
        source_vector_field,
        source_language_field,
        translation_text_field,
        translation_language_field,
        translation_vector_field
    ],
    description="Collection for storing translations with source text, translation text, languages, and translation embeddings"
)

# Create collection if it doesn't exist, otherwise use existing one
if utility.has_collection(MILVUS_COLLECTION_NAME):
    print(f"Collection '{MILVUS_COLLECTION_NAME}' already exists. Using existing collection.")
    collection = Collection(MILVUS_COLLECTION_NAME)
    
    # Check and create indexes if they don't exist
    # Note: Collection must be released before creating indexes
    index_params = {
        "metric_type": "L2",
        "index_type": "IVF_FLAT",
        "params": {"nlist": 1024}
    }
    
    # Release collection if loaded (needed before creating indexes)
    try:
        collection.release()
    except:
        pass  # Collection might not be loaded
    
    # Check if indexes exist, create if missing
    # Use try-except to check if index exists (has_index has parameter issues)
    def index_exists(collection, field_name):
        """Check if an index exists for a given field name."""
        try:
            # Try to get indexes - if field has index, it will be in the list
            indexes = collection.indexes
            return any(idx.field_name == field_name for idx in indexes)
        except Exception:
            # If we can't check, assume it doesn't exist
            return False
    
    if not index_exists(collection, "source_vector"):
        print("Creating index for source_vector field...")
        collection.create_index(field_name="source_vector", index_params=index_params)
    
    if not index_exists(collection, "translation_vector"):
        print("Creating index for translation_vector field...")
        collection.create_index(field_name="translation_vector", index_params=index_params)
    
    # Load collection after ensuring indexes exist
    collection.load()
else:
    print(f"Creating new collection '{MILVUS_COLLECTION_NAME}' with custom schema.")
    collection = Collection(name=MILVUS_COLLECTION_NAME, schema=schema)
    # Create indexes on both vector fields for efficient search
    index_params = {
        "metric_type": "L2",
        "index_type": "IVF_FLAT",
        "params": {"nlist": 1024}
    }
    print("Creating indexes for vector fields...")
    collection.create_index(field_name="source_vector", index_params=index_params)
    collection.create_index(field_name="translation_vector", index_params=index_params)
    collection.load()

# Now use langchain_milvus with the existing collection
# Map translation_text to the text field and translation_vector to the vector field
vectorstore = Milvus(
    embedding_function=embedding_model,
    connection_args={
        "uri": MILVUS_URI,
        "token": MILVUS_TOKEN
    },
    collection_name=MILVUS_COLLECTION_NAME,
    vector_field="source_vector"
)

from langchain_core.stores import InMemoryByteStore

# This saves the parent documents to a folder on your disk
store = InMemoryByteStore()
# Out:
# Collection 'translations' already exists. Using existing collection.

# %%
# Helper function to insert translation data with all custom fields
# Note: langchain_milvus only handles text_field and vector_field automatically
# For full control over all fields, use pymilvus directly:

def insert_translation_data(
    source_text: str,
    source_language: str,
    translation_text: str,
    translation_language: str,
    embedding_model: GoogleGenerativeAIEmbeddings
):
    """
    Insert translation data with all custom schema fields.
    
    Args:
        source_text: Original source text
        source_language: Language code of source text (e.g., 'tib', 'en')
        translation_text: Translated text
        translation_language: Language code of translation (e.g., 'en', 'tib')
        embedding_model: Embedding model to generate vectors
    """
    # Generate embeddings for both source and translation text
    source_vector = embedding_model.embed_query(source_text)
    translation_vector = embedding_model.embed_query(translation_text)
    
    # Prepare data for insertion (pymilvus accepts list of dicts)
    # Note: id field is auto-generated, so we don't include it
    data = [{
        "source_text": source_text,
        "source_vector": source_vector,
        "source_language": source_language,
        "translation_text": translation_text,
        "translation_language": translation_language,
        "translation_vector": translation_vector
    }]
    
    # Insert into collection (id is auto-generated)
    collection.insert(data)
    collection.flush()  # Ensure data is written
    print(f"Inserted translation: {source_language} -> {translation_language}")

# Example usage:
insert_translation_data(
    source_text="བཀྲ་ཤིས་བདེ་ལེགས།",
    source_language="tib",
    translation_text="Hello, may you be well",
    translation_language="en",
    embedding_model=embedding_model
)
# Out:
# Inserted translation: tib -> en

# %%
# The splitter to create the large chunks (Parents)
parent_splitter = RecursiveCharacterTextSplitter(chunk_size=4000)

# The splitter to create the small chunks (Children)
child_splitter = RecursiveCharacterTextSplitter(chunk_size=400)

# %%
from langchain_classic.retrievers import ParentDocumentRetriever
from langchain_core.documents import Document

# Following the field schema defined earlier in the notebook
docs = [
    Document(
        page_content="བཀྲ་ཤིས་བདེ་ལེགས།",
        metadata={
            "source_text": "བཀྲ་ཤིས་བདེ་ལེགས།",
            "source_language": "tib",
            "translation_text": "Hello, may you be well",
            "translation_language": "en",
        }
    ),
    Document(
        page_content="Hello, may you be well",
        metadata={
            "source_text": "Hello, may you be well",
            "source_language": "en",
            "translation_text": "བཀྲ་ཤིས་བདེ་ལེགས།",
            "translation_language": "tib",
        }
    )
]

retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=child_splitter,
    parent_splitter=parent_splitter,
)

# Add documents to the retriever
retriever.add_documents(docs)

# Use it in your RAG pipeline
query = "What are the specific technical requirements for the project?"
# Out:
# 2026-01-05 17:05:07,666 [ERROR][handler]: RPC error: [insert_rows], <DataNotMatchException: (code=1, message=Attempt to insert an unexpected field `text` to collection without enabling dynamic field)>, <Time:{'RPC start': '2026-01-05 17:05:07.473569', 'RPC error': '2026-01-05 17:05:07.665271'}>
# Traceback:
# Traceback (most recent call last):
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py", line 263, in handler
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py", line 322, in handler
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py", line 196, in handler
#     raise e from e
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py", line 166, in handler
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py", line 671, in insert_rows
#     request = self._prepare_row_insert_request(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py", line 727, in _prepare_row_insert_request
#     return Prepare.row_insert_param(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py", line 1058, in row_insert_param
#     return cls._parse_row_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py", line 786, in _parse_row_request
#     raise DataNotMatchException(
# pymilvus.exceptions.DataNotMatchException: <DataNotMatchException: (code=1, message=Attempt to insert an unexpected field `text` to collection without enabling dynamic field)>
#  (decorators.py:267)
# Failed to insert batch starting at entity: 1/2. First entity data: {'text': 'བཀྲ་ཤིས་བདེ་ལེགས།', 'source_vector': '[0.04358331114053726, -0.0034767580218613148, -0.05901914834976196, -0.019960958510637283, 0.061847880482673645, 0.00154032779391855, 0.005782857537269592, -0.04265255853533745, 0.0036057038232684135, 0.04078749194741249]... (truncated, total len: 768)', 'source_text': 'བཀྲ་ཤིས་བདེ་ལེགས།', 'source_language': 'tib', 'translation_text': 'Hello, may you be well', 'translation_language': 'en'}
# ---------------------------------------------------------------------------
# DataNotMatchException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[38], line 34
#      33 # Add documents to the retriever
# ---> 34 retriever.add_documents(docs)
#      36 # Use it in your RAG pipeline
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_classic\retrievers\parent_document_retriever.py:143, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     138 docs, full_docs = self._split_docs_for_adding(
#     139     documents,
#     140     ids,
#     141     add_to_docstore=add_to_docstore,
#     142 )
# --> 143 self.vectorstore.add_documents(docs, **kwargs)
#     144 if add_to_docstore:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:2272, in Milvus.add_documents(self, documents, **kwargs)
#    2271 metadatas = [doc.metadata for doc in documents]
# -> 2272 return self.add_texts(texts, metadatas, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1403, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1401     transposed_embeddings = embeddings[0] if len(embeddings) > 0 else []
# -> 1403 return self.add_embeddings(
#    1404     texts=texts,
#    1405     embeddings=transposed_embeddings,
#    1406     metadatas=metadatas,
#    1407     timeout=timeout,
#    1408     batch_size=batch_size,
#    1409     ids=ids,
#    1410     **kwargs,
#    1411 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1512, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1511     except MilvusException as e:
# -> 1512         self._handle_batch_operation_exception(
#    1513             e, batch_insert_list, i, total_count, "insert"
#    1514         )
#    1515 return pks
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1553, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1546 logger.error(
#    1547     "Failed to %s batch starting at entity: %s/%s. First entity data: %s",
#    1548     operation_name,
#    (...)   1551     log_entity,
#    1552 )
# -> 1553 raise e
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1504, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1503 timeout = self.timeout or timeout
# -> 1504 res = self.client.insert(
#    1505     self.collection_name,
#    1506     batch_insert_list,
#    1507     timeout=timeout,
#    1508     **kwargs,
#    1509 )
#    1510 pks.extend(res["ids"])
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:227, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     226 except Exception as ex:
# --> 227     raise ex from ex
#     228 return OmitZeroDict(
#     229     {
#     230         "insert_count": res.insert_count,
#    (...)    233     }
#     234 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:223, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     222 try:
# --> 223     res = conn.insert_rows(
#     224         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     225     )
#     226 except Exception as ex:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:271, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     267     LOGGER.error(
#     268         f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>\n"
#     269         f"Traceback:\n{tb_str}"
#     270     )
# --> 271     raise e from e
#     272 except grpc.FutureTimeoutError as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:263, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     262     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 263     return func(*args, **kwargs)
#     264 except MilvusException as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:322, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     321     self.set_onetime_loglevel(level)
# --> 322 return func(self, *args, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:196, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     195     else:
# --> 196         raise e from e
#     197 except Exception as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:166, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     165 try:
# --> 166     return func(*args, **kwargs)
#     167 except grpc.RpcError as e:
#     168     # Do not retry on these codes
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:671, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     670     schema = self.update_schema(collection_name, timeout, **kwargs)
# --> 671     request = self._prepare_row_insert_request(
#     672         collection_name, entities, partition_name, schema, timeout, **kwargs
#     673     )
#     674 except Exception as ex:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:727, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     725 namespace = kwargs.get("namespace")
# --> 727 return Prepare.row_insert_param(
#     728     collection_name,
#     729     entity_rows,
#     730     partition_name,
#     731     fields_info,
#     732     struct_fields_info,
#     733     enable_dynamic=enable_dynamic,
#     734     schema_timestamp=schema_timestamp,
#     735     namespace=namespace,
#     736 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:1058, in Prepare.row_insert_param(cls, collection_name, entities, partition_name, fields_info, struct_fields_info, schema_timestamp, enable_dynamic, namespace)
#    1050 request = milvus_types.InsertRequest(
#    1051     collection_name=collection_name,
#    1052     partition_name=p_name,
#    (...)   1055     namespace=namespace,
#    1056 )
# -> 1058 return cls._parse_row_request(
#    1059     request, fields_info, struct_fields_info, enable_dynamic, entities
#    1060 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:786, in Prepare._parse_row_request(request, fields_info, struct_fields_info, enable_dynamic, entities)
#     785     if not enable_dynamic:
# --> 786         raise DataNotMatchException(
#     787             message=ExceptionsMessage.InsertUnexpectedField % k
#     788         )
#     790 if k in fields_data:
#
# DataNotMatchException: <DataNotMatchException: (code=1, message=Attempt to insert an unexpected field `text` to collection without enabling dynamic field)>
#
# The above exception was the direct cause of the following exception:
#
# DataNotMatchException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[38], line 34
#      33 # Add documents to the retriever
# ---> 34 retriever.add_documents(docs)
#      36 # Use it in your RAG pipeline
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_classic\retrievers\parent_document_retriever.py:143, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     138 docs, full_docs = self._split_docs_for_adding(
#     139     documents,
#     140     ids,
#     141     add_to_docstore=add_to_docstore,
#     142 )
# --> 143 self.vectorstore.add_documents(docs, **kwargs)
#     144 if add_to_docstore:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:2272, in Milvus.add_documents(self, documents, **kwargs)
#    2271 metadatas = [doc.metadata for doc in documents]
# -> 2272 return self.add_texts(texts, metadatas, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1403, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1401     transposed_embeddings = embeddings[0] if len(embeddings) > 0 else []
# -> 1403 return self.add_embeddings(
#    1404     texts=texts,
#    1405     embeddings=transposed_embeddings,
#    1406     metadatas=metadatas,
#    1407     timeout=timeout,
#    1408     batch_size=batch_size,
#    1409     ids=ids,
#    1410     **kwargs,
#    1411 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1512, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1511     except MilvusException as e:
# -> 1512         self._handle_batch_operation_exception(
#    1513             e, batch_insert_list, i, total_count, "insert"
#    1514         )
#    1515 return pks
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1553, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1546 logger.error(
#    1547     "Failed to %s batch starting at entity: %s/%s. First entity data: %s",
#    1548     operation_name,
#    (...)   1551     log_entity,
#    1552 )
# -> 1553 raise e
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1504, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1503 timeout = self.timeout or timeout
# -> 1504 res = self.client.insert(
#    1505     self.collection_name,
#    1506     batch_insert_list,
#    1507     timeout=timeout,
#    1508     **kwargs,
#    1509 )
#    1510 pks.extend(res["ids"])
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:227, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     226 except Exception as ex:
# --> 227     raise ex from ex
#     228 return OmitZeroDict(
#     229     {
#     230         "insert_count": res.insert_count,
#    (...)    233     }
#     234 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:223, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     222 try:
# --> 223     res = conn.insert_rows(
#     224         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     225     )
#     226 except Exception as ex:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:271, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     267     LOGGER.error(
#     268         f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>\n"
#     269         f"Traceback:\n{tb_str}"
#     270     )
# --> 271     raise e from e
#     272 except grpc.FutureTimeoutError as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:263, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     262     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 263     return func(*args, **kwargs)
#     264 except MilvusException as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:322, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     321     self.set_onetime_loglevel(level)
# --> 322 return func(self, *args, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:196, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     195     else:
# --> 196         raise e from e
#     197 except Exception as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:166, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     165 try:
# --> 166     return func(*args, **kwargs)
#     167 except grpc.RpcError as e:
#     168     # Do not retry on these codes
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:671, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     670     schema = self.update_schema(collection_name, timeout, **kwargs)
# --> 671     request = self._prepare_row_insert_request(
#     672         collection_name, entities, partition_name, schema, timeout, **kwargs
#     673     )
#     674 except Exception as ex:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:727, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     725 namespace = kwargs.get("namespace")
# --> 727 return Prepare.row_insert_param(
#     728     collection_name,
#     729     entity_rows,
#     730     partition_name,
#     731     fields_info,
#     732     struct_fields_info,
#     733     enable_dynamic=enable_dynamic,
#     734     schema_timestamp=schema_timestamp,
#     735     namespace=namespace,
#     736 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:1058, in Prepare.row_insert_param(cls, collection_name, entities, partition_name, fields_info, struct_fields_info, schema_timestamp, enable_dynamic, namespace)
#    1050 request = milvus_types.InsertRequest(
#    1051     collection_name=collection_name,
#    1052     partition_name=p_name,
#    (...)   1055     namespace=namespace,
#    1056 )
# -> 1058 return cls._parse_row_request(
#    1059     request, fields_info, struct_fields_info, enable_dynamic, entities
#    1060 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:786, in Prepare._parse_row_request(request, fields_info, struct_fields_info, enable_dynamic, entities)
#     785     if not enable_dynamic:
# --> 786         raise DataNotMatchException(
#     787             message=ExceptionsMessage.InsertUnexpectedField % k
#     788         )
#     790 if k in fields_data:
#
# DataNotMatchException: <DataNotMatchException: (code=1, message=Attempt to insert an unexpected field `text` to collection without enabling dynamic field)>
#
# The above exception was the direct cause of the following exception:
#
# DataNotMatchException                     Traceback (most recent call last)
# Cell In[38], line 34
#      26 retriever = ParentDocumentRetriever(
#      27     vectorstore=vectorstore,
#      28     docstore=store,
#      29     child_splitter=child_splitter,
#      30     parent_splitter=parent_splitter,
#      31 )
#      33 # Add documents to the retriever
# ---> 34 retriever.add_documents(docs)
#      36 # Use it in your RAG pipeline
#      37 query = "What are the specific technical requirements for the project?"
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_classic\retrievers\parent_document_retriever.py:143, in ParentDocumentRetriever.add_documents(self, documents, ids, add_to_docstore, **kwargs)
#     123 """Adds documents to the docstore and vectorstores.
#     124
#     125 Args:
#    (...)    136     **kwargs: additional keyword arguments passed to the `VectorStore`.
#     137 """
#     138 docs, full_docs = self._split_docs_for_adding(
#     139     documents,
#     140     ids,
#     141     add_to_docstore=add_to_docstore,
#     142 )
# --> 143 self.vectorstore.add_documents(docs, **kwargs)
#     144 if add_to_docstore:
#     145     self.docstore.mset(full_docs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:2272, in Milvus.add_documents(self, documents, **kwargs)
#    2270 texts = [doc.page_content for doc in documents]
#    2271 metadatas = [doc.metadata for doc in documents]
# -> 2272 return self.add_texts(texts, metadatas, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1403, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1395 else:
#    1396     # transposed_embeddings = [
#    1397     #     f1(a),
#    1398     #     f1(b),
#    1399     #     f1(c)
#    1400     # ]
#    1401     transposed_embeddings = embeddings[0] if len(embeddings) > 0 else []
# -> 1403 return self.add_embeddings(
#    1404     texts=texts,
#    1405     embeddings=transposed_embeddings,
#    1406     metadatas=metadatas,
#    1407     timeout=timeout,
#    1408     batch_size=batch_size,
#    1409     ids=ids,
#    1410     **kwargs,
#    1411 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1512, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1510         pks.extend(res["ids"])
#    1511     except MilvusException as e:
# -> 1512         self._handle_batch_operation_exception(
#    1513             e, batch_insert_list, i, total_count, "insert"
#    1514         )
#    1515 return pks
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1553, in Milvus._handle_batch_operation_exception(self, e, batch_list, batch_index, total_count, operation_name)
#    1545         log_entity[k] = v
#    1546 logger.error(
#    1547     "Failed to %s batch starting at entity: %s/%s. First entity data: %s",
#    1548     operation_name,
#    (...)   1551     log_entity,
#    1552 )
# -> 1553 raise e
#
# File d:\work\langraph-api\.venv\Lib\site-packages\langchain_milvus\vectorstores\milvus.py:1504, in Milvus.add_embeddings(self, texts, embeddings, metadatas, timeout, batch_size, ids, **kwargs)
#    1502 try:
#    1503     timeout = self.timeout or timeout
# -> 1504     res = self.client.insert(
#    1505         self.collection_name,
#    1506         batch_insert_list,
#    1507         timeout=timeout,
#    1508         **kwargs,
#    1509     )
#    1510     pks.extend(res["ids"])
#    1511 except MilvusException as e:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:227, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     223     res = conn.insert_rows(
#     224         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     225     )
#     226 except Exception as ex:
# --> 227     raise ex from ex
#     228 return OmitZeroDict(
#     229     {
#     230         "insert_count": res.insert_count,
#    (...)    233     }
#     234 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:223, in MilvusClient.insert(self, collection_name, data, timeout, partition_name, **kwargs)
#     221 # Insert into the collection.
#     222 try:
# --> 223     res = conn.insert_rows(
#     224         collection_name, data, partition_name=partition_name, timeout=timeout, **kwargs
#     225     )
#     226 except Exception as ex:
#     227     raise ex from ex
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:271, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     266     tb_str = traceback.format_exc()
#     267     LOGGER.error(
#     268         f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>\n"
#     269         f"Traceback:\n{tb_str}"
#     270     )
# --> 271     raise e from e
#     272 except grpc.FutureTimeoutError as e:
#     273     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:263, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     261 try:
#     262     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 263     return func(*args, **kwargs)
#     264 except MilvusException as e:
#     265     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:322, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     320 if level:
#     321     self.set_onetime_loglevel(level)
# --> 322 return func(self, *args, **kwargs)
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:196, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     194         back_off = min(back_off * back_off_multiplier, max_back_off)
#     195     else:
# --> 196         raise e from e
#     197 except Exception as e:
#     198     raise e from e
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\decorators.py:166, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     164 while True:
#     165     try:
# --> 166         return func(*args, **kwargs)
#     167     except grpc.RpcError as e:
#     168         # Do not retry on these codes
#     169         if e.code() in IGNORE_RETRY_CODES:
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:671, in GrpcHandler.insert_rows(self, collection_name, entities, partition_name, schema, timeout, **kwargs)
#     668 except DataNotMatchException:
#     669     # try to update schema and retry
#     670     schema = self.update_schema(collection_name, timeout, **kwargs)
# --> 671     request = self._prepare_row_insert_request(
#     672         collection_name, entities, partition_name, schema, timeout, **kwargs
#     673     )
#     674 except Exception as ex:
#     675     raise ex from ex
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\grpc_handler.py:727, in GrpcHandler._prepare_row_insert_request(self, collection_name, entity_rows, partition_name, schema, timeout, **kwargs)
#     724 enable_dynamic = schema.get("enable_dynamic_field", False)
#     725 namespace = kwargs.get("namespace")
# --> 727 return Prepare.row_insert_param(
#     728     collection_name,
#     729     entity_rows,
#     730     partition_name,
#     731     fields_info,
#     732     struct_fields_info,
#     733     enable_dynamic=enable_dynamic,
#     734     schema_timestamp=schema_timestamp,
#     735     namespace=namespace,
#     736 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:1058, in Prepare.row_insert_param(cls, collection_name, entities, partition_name, fields_info, struct_fields_info, schema_timestamp, enable_dynamic, namespace)
#    1049 p_name = partition_name if isinstance(partition_name, str) else ""
#    1050 request = milvus_types.InsertRequest(
#    1051     collection_name=collection_name,
#    1052     partition_name=p_name,
#    (...)   1055     namespace=namespace,
#    1056 )
# -> 1058 return cls._parse_row_request(
#    1059     request, fields_info, struct_fields_info, enable_dynamic, entities
#    1060 )
#
# File d:\work\langraph-api\.venv\Lib\site-packages\pymilvus\client\prepare.py:786, in Prepare._parse_row_request(request, fields_info, struct_fields_info, enable_dynamic, entities)
#     781         raise DataNotMatchException(
#     782             message=ExceptionsMessage.InsertUnexpectedFunctionOutputField % k
#     783         )
#     785     if not enable_dynamic:
# --> 786         raise DataNotMatchException(
#     787             message=ExceptionsMessage.InsertUnexpectedField % k
#     788         )
#     790 if k in fields_data:
#     791     field_info, field_data = field_info_map[k], fields_data[k]
#
# DataNotMatchException: <DataNotMatchException: (code=1, message=Attempt to insert an unexpected field `text` to collection without enabling dynamic field)>
